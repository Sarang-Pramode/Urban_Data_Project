# %% [markdown]
# ## " The replacement of low-income, inner-city working class residents by middle- or upper-class house-holds, either through the market for existing housing or demolition to make way for new up housing construction "
#
# - Median household income
# - Home Value
# - Rent
# - Education
# - Displacement of minor communities
# - Age
#
# """
#
# gdf_2010['gen_INDEX'] = \
# gdf_2010['Median_Age_norm']* \
# (gdf_2010['Total_Bachelors_or_higher'] \
# (gdf_2010['Total_Houses_Built_2005_to_2010']+gdf_2010['Total_Houses_Built_2000_to_2004'])/gdf_2010['Total_House_Count']* \
# (gdf_2010['tot_fams_1-10k']+gdf_2010['tot_fams_1-15k']+gdf_2010['tot_fams_1-25k'])/gdf_2010['total_fams']
#
# """
#
# # NOTE : <b>ENSURE ALL METRICS ARE ON THE SAME SCALE</b>

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import math

pd.set_option('max_row',50)

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(1,100))
scaler10 = MinMaxScaler(feature_range=(1,10))

# %% [markdown]
# # Dataset Created
#  - g2010.csv - neighbourhood snapshot of collective 2010 data
#  - g2019.csv - neighbourhood snapshot of collective 2019 data

# %%
#Read CSV files
g2010 = pd.read_csv('g2010.csv')
g2019 = pd.read_csv('g2019.csv')

#Create Copy
g2010_df = g2010.copy()
g2019_df = g2019.copy()

# %%
g2010.columns
# Out:
# Index(['Unnamed: 0', 'ct2010', 'Census_Tract', 'boro_code', 'shape_area',
#        'shape_leng', 'geometry', 'Total_Population', 'Total_Male_Population',
#        'Total_Female_Population', 'Per_Population_25_to_34_yrs',
#        'Per_Population_35_to_44_yrs', 'Per_Population_45_to_54_yrs',
#        'Median_Age', 'Total_Population_18_to_24_yrs',
#        'Total_High_School_Graduates', 'Total_College_or_Associate_Degree',
#        'Total_Bachelors_or_higher', 'Total_Population_25_yrs_or_over',
#        'Total_Population_25_to_34_yrs', 'Total_House_Count',
#        'Total_Houses_Built_2005_to_2010', 'Total_Houses_Built_2000_to_2004',
#        'GEO_ID_x', 'tot_occ_hous_units', 'med_hh_income',
#        'med_monthly_hous_cost', 'GEO_ID_y', 'tot_fams', 'tot_fams_1-10k',
#        'tot_fams_10-15k', 'tot_fams_15-25k'],
#       dtype='object')

# %%
g2019.columns
# Out:
# Index(['Unnamed: 0', 'ct2010', 'Census_Tract', 'boro_code', 'shape_area',
#        'shape_leng', 'geometry', 'Total_Population', 'Total_Male_Population',
#        'Total_Female_Population', 'Per_Population_25_to_34_yrs',
#        'Per_Population_35_to_44_yrs', 'Per_Population_45_to_54_yrs',
#        'Median_Age', 'Total_Population_18_to_24_yrs',
#        'Total_High_School_Graduates', 'Total_College_or_Associate_Degree',
#        'Total_Bachelors_or_higher', 'Total_Population_25_yrs_or_over',
#        'Total_Population_25_to_34_yrs', 'Total_House_Count',
#        'Total_Houses_Built_2014_to_2019', 'Total_Houses_Built_2010_to_2013',
#        'GEO_ID_x', 'tot_occ_hous_units', 'med_hh_income',
#        'med_monthly_hous_cost', 'GEO_ID_y', 'tot_fams', 'tot_fams_1-10k',
#        'tot_fams_10-15k', 'tot_fams_15-25k'],
#       dtype='object')

# %%
dataset = [g2010_df,g2019_df]

# %%
for d in dataset:
    d.drop(d.columns[0],axis=1,inplace=True)

# %%
dataset[0].head()
# Out:
#    ct2010  Census_Tract  boro_code    shape_area   shape_leng  \
# 0     900           9.0          5  2.497010e+06  7729.016794
# 1    9800          98.0          1  1.906016e+06  5534.200306
# 2   10200         102.0          1  1.860993e+06  5687.802439
# 3   10400         104.0          1  1.864600e+06  5693.036367
# 4   11300         113.0          1  1.890907e+06  5699.860712
#
#                                             geometry  Total_Population  \
# 0  POLYGON ((-74.07920577013245 40.64343078374567...              1880
# 1  POLYGON ((-73.96432543478758 40.75638153099091...              7045
# 2  POLYGON ((-73.97124277307127 40.76093641847906...               189
# 3  POLYGON ((-73.97445730550224 40.76229308352487...               981
# 4  POLYGON ((-73.98411754823195 40.7548420534646,...               195
#
#    Total_Male_Population  Total_Female_Population Per_Population_25_to_34_yrs  \
# 0                    909                      971                        10.6
# 1                   2931                     4114                        30.9
# 2                     81                      108                         7.9
# 3                    444                      537                        14.1
# 4                     89                      106                        14.9
#
#    ... Total_Houses_Built_2000_to_2004              GEO_ID_x  \
# 0  ...                              44  1400000US36085000900
# 1  ...                               0  1400000US36061009800
# 2  ...                               0  1400000US36061010200
# 3  ...                               6  1400000US36061010400
# 4  ...                               9  1400000US36061011300
#
#   tot_occ_hous_units  med_hh_income med_monthly_hous_cost  \
# 0                693          56192                  1234
# 1               4253         101191                  2078
# 2                 89          41809                  1193
# 3                674          85455                  1785
# 4                 75         113618                  1538
#
#                GEO_ID_y tot_fams  tot_fams_1-10k  tot_fams_10-15k  \
# 0  1400000US36085000900     1487             290               21
# 1  1400000US36061009800     6772             390              161
# 2  1400000US36061010200      189              27               23
# 3  1400000US36061010400      943              51               44
# 4  1400000US36061011300      195              45                9
#
#    tot_fams_15-25k
# 0               73
# 1              404
# 2               85
# 3               93
# 4               31
#
# [5 rows x 31 columns]

# %%
mismatch_columns2019 = [ i for i in g2019 if i not in g2010 ]
mismatch_columns2010 = [ i for i in g2010 if i not in g2019 ]

# %%
#Mismatched Columns
print(mismatch_columns2010)
print(mismatch_columns2019)
# Out:
# ['Total_Houses_Built_2005_to_2010', 'Total_Houses_Built_2000_to_2004']
# ['Total_Houses_Built_2014_to_2019', 'Total_Houses_Built_2010_to_2013']

# %%
dataset[0].columns
# Out:
# Index(['ct2010', 'Census_Tract', 'boro_code', 'shape_area', 'shape_leng',
#        'geometry', 'Total_Population', 'Total_Male_Population',
#        'Total_Female_Population', 'Per_Population_25_to_34_yrs',
#        'Per_Population_35_to_44_yrs', 'Per_Population_45_to_54_yrs',
#        'Median_Age', 'Total_Population_18_to_24_yrs',
#        'Total_High_School_Graduates', 'Total_College_or_Associate_Degree',
#        'Total_Bachelors_or_higher', 'Total_Population_25_yrs_or_over',
#        'Total_Population_25_to_34_yrs', 'Total_House_Count',
#        'Total_Houses_Built_2005_to_2010', 'Total_Houses_Built_2000_to_2004',
#        'GEO_ID_x', 'tot_occ_hous_units', 'med_hh_income',
#        'med_monthly_hous_cost', 'GEO_ID_y', 'tot_fams', 'tot_fams_1-10k',
#        'tot_fams_10-15k', 'tot_fams_15-25k'],
#       dtype='object')

# %% [markdown]
# # Columns to consider for gentrification INDEX
#
# ### Version 1:
# Median Age
# Total_Bachelors_or_higher
# Total_Houses_Built_2005_to_2010
# Total_Houses_Built_2000_to_2004
# med_monthly_hous_cost
# tot_fams_1-10k
# tot_fams_1-15k
# tot_fams_1-25k

# %% [markdown]
# The format of your polygon is WKT, so you have to convert it to shapely Polygon. Following Geopandas docs (https://geopandas.readthedocs.io/en/latest/gallery/create_geopandas_from_pandas.html) do following

# %%
#Set Geometry for 2010 dataset
dataset[0]['geometry'] = gpd.GeoSeries.from_wkt(dataset[0]['geometry'])
gdf_2010 = gpd.GeoDataFrame(dataset[0],geometry="geometry")

#Set Geometry for 2019 dataset
dataset[1]['geometry'] = gpd.GeoSeries.from_wkt(dataset[1]['geometry'])
gdf_2019 = gpd.GeoDataFrame(dataset[1],geometry="geometry")

# %%
type(gdf_2010)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
gdf_2010.plot()
# Out:
# <AxesSubplot:>

# %%
gdf_2019.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Preprocessing all columns

# %% [markdown]
# ---
# ### ' - ' Character present in Median_Age -> replacing with Null
# ---

# %%
gdf_2010['Median_Age'].value_counts()
# Out:
# -       46
# 35.2    22
# 36.3    21
# 32.0    20
# 34.0    20
#         ..
# 60.0     1
# 58.1     1
# 84.4     1
# 63.8     1
# 62.1     1
# Name: Median_Age, Length: 339, dtype: int64

# %%
gdf_2010['Median_Age'] = gdf_2010['Median_Age'].replace('-',np.NaN)

# %%
gdf_2010['Median_Age'].isnull().sum()
# Out:
# 46

# %%
#Fill mean for null values in Median Age
gdf_2010['Median_Age'].fillna(gdf_2010['Median_Age'].astype('float').mean(),inplace=True)

# %%
gdf_2010['Median_Age'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # Adding frac_pop_25_to_54 - Fraction of Population between 25-54 yrs of age

# %%
gdf_2010['Per_Population_25_to_34_yrs'] = gdf_2010['Per_Population_25_to_34_yrs'].replace('-',np.NaN)
gdf_2010['Per_Population_35_to_44_yrs'] = gdf_2010['Per_Population_35_to_44_yrs'].replace('-',np.NaN)
gdf_2010['Per_Population_45_to_54_yrs'] = gdf_2010['Per_Population_45_to_54_yrs'].replace('-',np.NaN)

gdf_2010['Per_Population_25_to_34_yrs'].fillna(gdf_2010['Per_Population_25_to_34_yrs'].astype('float').mean(),inplace=True)
gdf_2010['Per_Population_35_to_44_yrs'].fillna(gdf_2010['Per_Population_35_to_44_yrs'].astype('float').mean(),inplace=True)
gdf_2010['Per_Population_45_to_54_yrs'].fillna(gdf_2010['Per_Population_45_to_54_yrs'].astype('float').mean(),inplace=True)

# %% [markdown]
# # Note - Values in Percentages

# %%
gdf_2010['frac_pop_25_to_54'] = gdf_2010['Per_Population_25_to_34_yrs'].astype(float)+gdf_2010['Per_Population_35_to_44_yrs'].astype(float)+gdf_2010['Per_Population_45_to_54_yrs'].astype(float)

# %%
gdf_2010['frac_pop_25_to_54']
# Out:
# 0       37.7
# 1       60.7
# 2       34.9
# 3       41.5
# 4       42.6
#         ...
# 2159    53.1
# 2160    60.7
# 2161    55.6
# 2162    56.9
# 2163    54.5
# Name: frac_pop_25_to_54, Length: 2164, dtype: float64

# %%
gdf_2010.columns
# Out:
# Index(['ct2010', 'Census_Tract', 'boro_code', 'shape_area', 'shape_leng',
#        'geometry', 'Total_Population', 'Total_Male_Population',
#        'Total_Female_Population', 'Per_Population_25_to_34_yrs',
#        'Per_Population_35_to_44_yrs', 'Per_Population_45_to_54_yrs',
#        'Median_Age', 'Total_Population_18_to_24_yrs',
#        'Total_High_School_Graduates', 'Total_College_or_Associate_Degree',
#        'Total_Bachelors_or_higher', 'Total_Population_25_yrs_or_over',
#        'Total_Population_25_to_34_yrs', 'Total_House_Count',
#        'Total_Houses_Built_2005_to_2010', 'Total_Houses_Built_2000_to_2004',
#        'GEO_ID_x', 'tot_occ_hous_units', 'med_hh_income',
#        'med_monthly_hous_cost', 'GEO_ID_y', 'tot_fams', 'tot_fams_1-10k',
#        'tot_fams_10-15k', 'tot_fams_15-25k', 'frac_pop_25_to_54'],
#       dtype='object')

# %%
#Normalize Median Age 
gdf_2010['Median_Age'] = gdf_2010['Median_Age'].astype(float)
# gdf_2010['Median_Age'] = (gdf_2010['Median_Age'] - gdf_2010['Median_Age'].mean())/gdf_2010['Median_Age'].std() #gives negative valus too
#gdf_2010['Median_Age']  = (gdf_2010['Median_Age']-gdf_2010['Median_Age'].min())/(gdf_2010['Median_Age'].max()-gdf_2010['Median_Age'].min())
gdf_2010['Median_Age'] = scaler.fit_transform(gdf_2010[["Median_Age"]])

# %%
gdf_2010['Median_Age']
# Out:
# 0       36.660598
# 1       39.750325
# 2       61.507152
# 3       55.585176
# 4       50.693108
#           ...
# 2159    45.543563
# 2160    36.403121
# 2161    38.076723
# 2162    33.055917
# 2163    41.681404
# Name: Median_Age, Length: 2164, dtype: float64

# %% [markdown]
# ---
# Note : This column represents a % of the population
# ### Total_Bachelors_or_higher - contains 0 - Not changing as this might contain valid data
# ### Total_Bachelors_or_higher - contains '-' - replacing with mean()
# ---

# %%
gdf_2010['Total_Bachelors_or_higher'].value_counts()
# Out:
# 0.0     308
# -        60
# 7.8      16
# 2.8      13
# 4.6      13
#        ...
# 48.0      1
# 75.9      1
# 33.8      1
# 53.2      1
# 80.7      1
# Name: Total_Bachelors_or_higher, Length: 565, dtype: int64

# %%
gdf_2010['Total_Bachelors_or_higher'] = gdf_2010['Total_Bachelors_or_higher'].replace('-',np.NaN)

# %%
gdf_2010['Total_Bachelors_or_higher'].fillna(gdf_2010['Total_Bachelors_or_higher'].astype('float').mean(),inplace=True)

# %%
gdf_2010['Total_Bachelors_or_higher'].value_counts()
# Out:
# 0.0                 308
# 18.3528041825095     60
# 7.8                  16
# 2.8                  13
# 4.6                  13
#                    ...
# 48.0                  1
# 75.9                  1
# 33.8                  1
# 53.2                  1
# 80.7                  1
# Name: Total_Bachelors_or_higher, Length: 565, dtype: int64

# %%
#GEN INDEX
gdf_2010['gen_INDEX'] = \
gdf_2010['frac_pop_25_to_54']+\
gdf_2010['Total_Bachelors_or_higher'].astype(float)

# %%
fig,ax = plt.subplots(figsize=(15,15))
gdf_2010.plot(column='gen_INDEX',ax=ax,legend=True)
plt.title('GEN INDEX - Age+Education')
# Out:
# Text(0.5, 1.0, 'GEN INDEX - Age+Education')

# %% [markdown]
# ---
# ### Total_Houses_Built_2005_to_2010 ; Total_Houses_Built_2000_to_2004 - contains 0 - Not changing as this might contain valid data
# ---

# %%
gdf_2010['Total_Houses_Built_2005_to_2010'].value_counts()
# Out:
# 0      1174
# 10       34
# 11       30
# 13       26
# 12       25
#        ...
# 398       1
# 115       1
# 128       1
# 217       1
# 401       1
# Name: Total_Houses_Built_2005_to_2010, Length: 189, dtype: int64

# %%
gdf_2010['Total_Houses_Built_2000_to_2004'].value_counts()
# Out:
# 0      981
# 9       34
# 10      30
# 24      26
# 11      25
#       ...
# 102      1
# 356      1
# 431      1
# 170      1
# 225      1
# Name: Total_Houses_Built_2000_to_2004, Length: 277, dtype: int64

# %% [markdown]
# ---
# Total_House_Count - contains 0 , replacing by mean
#
# ---

# %%
gdf_2010['Total_House_Count'].value_counts()
# Out:
# 0       48
# 1026     6
# 2066     5
# 667      5
# 1300     5
#         ..
# 1542     1
# 1611     1
# 1654     1
# 1208     1
# 1642     1
# Name: Total_House_Count, Length: 1464, dtype: int64

# %%
gdf_2010['Total_House_Count'] = gdf_2010['Total_House_Count'].replace(0,gdf_2010['Total_House_Count'].mean())

# %%
gdf_2010['Total_House_Count'].value_counts()
# Out:
# 1545.020333    48
# 1026.000000     6
# 2066.000000     5
# 667.000000      5
# 1300.000000     5
#                ..
# 1542.000000     1
# 1611.000000     1
# 1654.000000     1
# 1208.000000     1
# 1642.000000     1
# Name: Total_House_Count, Length: 1464, dtype: int64

# %%
# % of construction occured in each tract between 2000-2010

gdf_2010['frac_Total_Houses_Built_2000_to_2010'] = \
    (gdf_2010['Total_Houses_Built_2005_to_2010']+ \
    gdf_2010['Total_Houses_Built_2000_to_2004'] )/ gdf_2010['Total_House_Count']

# %%
gdf_2010['frac_Total_Houses_Built_2000_to_2010'].value_counts()
# Out:
# 0.000000    702
# 0.013333      2
# 0.009761      2
# 0.023033      2
# 0.061224      2
#            ...
# 0.037037      1
# 0.111032      1
# 0.119766      1
# 0.012784      1
# 0.026188      1
# Name: frac_Total_Houses_Built_2000_to_2010, Length: 1449, dtype: int64

# %%
#Scaling
gdf_2010['frac_Total_Houses_Built_2000_to_2010'] = gdf_2010['frac_Total_Houses_Built_2000_to_2010']*100

# %%
#Adding frac_Total_Houses_Built_2000_to_2010 to GEN_INDEX - Scaling to (0,100)
#GEN INDEX
gdf_2010['gen_INDEX'] = \
gdf_2010['frac_pop_25_to_54']+\
gdf_2010['Total_Bachelors_or_higher'].astype(float)+\
gdf_2010['frac_Total_Houses_Built_2000_to_2010']

# %%
fig,ax = plt.subplots(figsize=(15,15))
gdf_2010.plot(column='gen_INDEX',ax=ax,legend=True,cmap='OrRd')
plt.title('GEN INDEX - Age+Education+Housing')
# Out:
# Text(0.5, 1.0, 'GEN INDEX - Age+Education+Housing')

# %% [markdown]
# ---
# tot_fams - has 0 , replacing by mean()
#
# ---

# %%
gdf_2010['tot_fams'].value_counts()
# Out:
# 0       44
# 3341     6
# 2053     4
# 1455     4
# 2934     4
#         ..
# 1721     1
# 3562     1
# 682      1
# 2429     1
# 2192     1
# Name: tot_fams, Length: 1725, dtype: int64

# %%
gdf_2010['tot_fams'] = gdf_2010['tot_fams'].replace(0,gdf_2010['tot_fams'].mean())

# %%
gdf_2010['tot_fams'].value_counts()
# Out:
# 3050.945471    44
# 3341.000000     6
# 2053.000000     4
# 1455.000000     4
# 2934.000000     4
#                ..
# 1721.000000     1
# 3562.000000     1
# 682.000000      1
# 2429.000000     1
# 2192.000000     1
# Name: tot_fams, Length: 1725, dtype: int64

# %%
gdf_2010.columns
# Out:
# Index(['ct2010', 'Census_Tract', 'boro_code', 'shape_area', 'shape_leng',
#        'geometry', 'Total_Population', 'Total_Male_Population',
#        'Total_Female_Population', 'Per_Population_25_to_34_yrs',
#        'Per_Population_35_to_44_yrs', 'Per_Population_45_to_54_yrs',
#        'Median_Age', 'Total_Population_18_to_24_yrs',
#        'Total_High_School_Graduates', 'Total_College_or_Associate_Degree',
#        'Total_Bachelors_or_higher', 'Total_Population_25_yrs_or_over',
#        'Total_Population_25_to_34_yrs', 'Total_House_Count',
#        'Total_Houses_Built_2005_to_2010', 'Total_Houses_Built_2000_to_2004',
#        'GEO_ID_x', 'tot_occ_hous_units', 'med_hh_income',
#        'med_monthly_hous_cost', 'GEO_ID_y', 'tot_fams', 'tot_fams_1-10k',
#        'tot_fams_10-15k', 'tot_fams_15-25k', 'frac_pop_25_to_54', 'gen_INDEX',
#        'frac_Total_Houses_Built_2000_to_2010'],
#       dtype='object')

# %%
(gdf_2010['tot_fams_1-10k']+gdf_2010['tot_fams_10-15k']+gdf_2010['tot_fams_15-25k']).value_counts()
# Out:
# 0       49
# 723      6
# 647      6
# 1113     5
# 1056     5
#         ..
# 1325     1
# 2589     1
# 1745     1
# 845      1
# 2450     1
# Length: 1397, dtype: int64

# %%
gdf_2010['tot_fams_1-25k'] = gdf_2010['tot_fams_1-10k']+gdf_2010['tot_fams_10-15k']+gdf_2010['tot_fams_15-25k']

# %%
gdf_2010['tot_fams_1-25k'] = gdf_2010['tot_fams_1-25k'].replace(0,gdf_2010['tot_fams_1-25k'].mean())

# %%
gdf_2010['frac_tot_fams_1-25k'] = gdf_2010['tot_fams_1-25k']/gdf_2010['tot_fams']

# %%
#get index of errorneous values in frac_tot_fams_1-25k
[[i,v] for i,v in enumerate(gdf_2010['frac_tot_fams_1-25k']) if v > 1]
# Out:
# [[1978, 18.135824511286618],
#  [2021, 18.702569027264325],
#  [2136, 10.318658773663076],
#  [2149, 85.4974584103512],
#  [2155, 26.020965603150366]]

# %%
#replacing errorneous values by 1
gdf_2010['frac_tot_fams_1-25k'].iloc[1978] = 1
gdf_2010['frac_tot_fams_1-25k'].iloc[2021] = 1
gdf_2010['frac_tot_fams_1-25k'].iloc[2021] = 1
gdf_2010['frac_tot_fams_1-25k'].iloc[2149] = 1
gdf_2010['frac_tot_fams_1-25k'].iloc[2155] = 1
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
gdf_2010['frac_tot_fams_1-25k'].value_counts()
# Out:
# 0.392326    44
# 1.000000     5
# 0.333333     2
# 0.500000     2
# 0.285714     2
#             ..
# 0.263437     1
# 0.301784     1
# 0.178040     1
# 0.190465     1
# 0.148723     1
# Name: frac_tot_fams_1-25k, Length: 2112, dtype: int64

# %%
gdf_2010['frac_low_income'] = (gdf_2010['frac_tot_fams_1-25k']) #lower the number of low income families, greater the gentrification
#gdf_2010['low_income'] = scaler.fit_transform(gdf_2010[["low_income"]])

# %%
#get index of errorneous values in low_income
[[i,v] for i,v in enumerate(gdf_2010['frac_low_income']) if v > 1]
# Out:
# [[2136, 10.318658773663076]]

# %%
#Handle Errorneous Values
gdf_2010['frac_low_income'].loc[2136] = 1

# %%
gdf_2010['frac_high_income']  = 1- gdf_2010['frac_low_income']

# %%
gdf_2010['frac_high_income'].sort_values()
# Out:
# 2136    0.000000
# 2149    0.000000
# 1978    0.000000
# 2155    0.000000
# 2021    0.000000
#           ...
# 1163    0.876625
# 1020    0.882952
# 1139    0.885621
# 1876    0.886673
# 1177    0.911111
# Name: frac_high_income, Length: 2164, dtype: float64

# %%
gdf_2010['frac_low_income'].sort_values
# Out:
# <bound method Series.sort_values of 0       0.258238
# 1       0.141022
# 2       0.714286
# 3       0.199364
# 4       0.435897
#           ...
# 2159    0.165833
# 2160    0.233987
# 2161    0.194841
# 2162    0.312535
# 2163    0.148723
# Name: frac_low_income, Length: 2164, dtype: float64>

# %%
gdf_2010['frac_low_income'] = gdf_2010['frac_low_income']*100 #SCaling to 100

# %%
gdf_2010['frac_high_income'] = gdf_2010['frac_high_income']*100 #SCaling to 100

# %%
#GEN INDEX
gdf_2010['gen_INDEX'] = \
gdf_2010['frac_pop_25_to_54']+\
gdf_2010['Total_Bachelors_or_higher'].astype(float)+\
gdf_2010['frac_Total_Houses_Built_2000_to_2010']+\
gdf_2010['frac_low_income']

# %%
gdf_2010['frac_low_income']
# Out:
# 0       25.823806
# 1       14.102185
# 2       71.428571
# 3       19.936373
# 4       43.589744
#           ...
# 2159    16.583274
# 2160    23.398741
# 2161    19.484097
# 2162    31.253513
# 2163    14.872263
# Name: frac_low_income, Length: 2164, dtype: float64

# %%
fig,ax = plt.subplots(figsize=(15,15))
gdf_2010.plot(column='gen_INDEX',ax=ax,legend=True,cmap='OrRd')
plt.title('GEN INDEX - Age+Education+Housing+Displacement')
# Out:
# Text(0.5, 1.0, 'GEN INDEX - Age+Education+Housing+Displacement')

# %%
gdf_2010.columns
# Out:
# Index(['ct2010', 'Census_Tract', 'boro_code', 'shape_area', 'shape_leng',
#        'geometry', 'Total_Population', 'Total_Male_Population',
#        'Total_Female_Population', 'Per_Population_25_to_34_yrs',
#        'Per_Population_35_to_44_yrs', 'Per_Population_45_to_54_yrs',
#        'Median_Age', 'Total_Population_18_to_24_yrs',
#        'Total_High_School_Graduates', 'Total_College_or_Associate_Degree',
#        'Total_Bachelors_or_higher', 'Total_Population_25_yrs_or_over',
#        'Total_Population_25_to_34_yrs', 'Total_House_Count',
#        'Total_Houses_Built_2005_to_2010', 'Total_Houses_Built_2000_to_2004',
#        'GEO_ID_x', 'tot_occ_hous_units', 'med_hh_income',
#        'med_monthly_hous_cost', 'GEO_ID_y', 'tot_fams', 'tot_fams_1-10k',
#        'tot_fams_10-15k', 'tot_fams_15-25k', 'frac_pop_25_to_54', 'gen_INDEX',
#        'frac_Total_Houses_Built_2000_to_2010', 'tot_fams_1-25k',
#        'frac_tot_fams_1-25k', 'frac_low_income', 'frac_high_income'],
#       dtype='object')

# %% [markdown]
# ---
# med_monthly_hous_cost - has '-' , replacing with mean()
# med_monthly_hous_cost - has '4,000+' , replacing with mean()
#
# ---

# %%
gdf_2010['med_monthly_hous_cost'].value_counts()
# Out:
# -       53
# 1088     8
# 1141     8
# 1169     8
# 1147     8
#         ..
# 1164     1
# 360      1
# 3483     1
# 1221     1
# 2188     1
# Name: med_monthly_hous_cost, Length: 1134, dtype: int64

# %%
#temp = gdf_2010['med_monthly_hous_cost'].index[gdf_2010['med_monthly_hous_cost']['4,000+']].tolist()

# %%
gdf_2010['med_monthly_hous_cost'] = gdf_2010['med_monthly_hous_cost'].replace('-',np.NaN)
gdf_2010['med_monthly_hous_cost'] = gdf_2010['med_monthly_hous_cost'].replace('4,000+',np.NaN)
gdf_2010['med_monthly_hous_cost'].fillna(gdf_2010['med_monthly_hous_cost'].astype('float').mean(),inplace=True)

# %%
gdf_2010['med_monthly_hous_cost'].value_counts()
# Out:
# 1281.5898530109057    55
# 1141                   8
# 1147                   8
# 1169                   8
# 1088                   8
#                       ..
# 1164                   1
# 360                    1
# 3483                   1
# 1221                   1
# 2188                   1
# Name: med_monthly_hous_cost, Length: 1133, dtype: int64

# %% [markdown]
# ---
# med_hh_income - has '-' , replacing with mean()
#
# ---

# %%
gdf_2010['med_hh_income'].value_counts()
# Out:
# -         54
# 36250      3
# 53125      3
# 49375      3
# 62083      3
#           ..
# 84263      1
# 83000      1
# 100605     1
# 100110     1
# 144167     1
# Name: med_hh_income, Length: 2027, dtype: int64

# %%
gdf_2010['med_hh_income'] = gdf_2010['med_hh_income'].replace('-',np.NaN)
gdf_2010['med_hh_income'] = gdf_2010['med_hh_income'].replace('250,000+',np.NaN)
gdf_2010['med_hh_income'].fillna(gdf_2010['med_hh_income'].astype('float').mean(),inplace=True)

# %%
gdf_2010['med_hh_income'].value_counts()
# Out:
# 54747.307728781416    55
# 52500                  3
# 39375                  3
# 55625                  3
# 62083                  3
#                       ..
# 84263                  1
# 83000                  1
# 100605                 1
# 100110                 1
# 144167                 1
# Name: med_hh_income, Length: 2026, dtype: int64

# %%
gdf_2010['med_monthly_hous_cost'].astype('float').max()
# Out:
# 3483.0

# %%
gdf_2010['frac_med_monthly_hous_cost'] = gdf_2010['med_monthly_hous_cost'].astype(float)/gdf_2010['med_hh_income'].astype(float)

# %%
#get index of errorneous values in low_income
[[i,v] for i,v in enumerate(gdf_2010['frac_med_monthly_hous_cost']) if v > 1]
# Out:
# []

# %%
gdf_2010['frac_med_monthly_hous_cost'].max()
# Out:
# 0.08106666666666666

# %% [markdown]
# # Scale values between 1-100 for frac median monthly housing costs

# %%
gdf_2010['frac_med_monthly_hous_cost'] = scaler.fit_transform(gdf_2010[['frac_med_monthly_hous_cost']])

# %%
gdf_2010['frac_med_monthly_hous_cost']
# Out:
# 0       18.451238
# 1       16.485171
# 2       27.521516
# 3       16.971878
# 4        6.828892
#           ...
# 2159    15.398058
# 2160    13.955224
# 2161    20.762007
# 2162    10.847213
# 2163     9.091950
# Name: frac_med_monthly_hous_cost, Length: 2164, dtype: float64

# %%
#GEN INDEX
gdf_2010['gen_INDEX'] = \
gdf_2010['frac_pop_25_to_54']+\
gdf_2010['Total_Bachelors_or_higher'].astype(float)+\
gdf_2010['frac_Total_Houses_Built_2000_to_2010']+\
gdf_2010['frac_low_income']+\
gdf_2010['frac_med_monthly_hous_cost']

# %%
fig,ax = plt.subplots(figsize=(15,15))
gdf_2010.plot(column='gen_INDEX',ax=ax,legend=True,cmap='OrRd')
plt.title('GEN INDEX - Age+Education+Housing+Displacement+Finance')
# Out:
# Text(0.5, 1.0, 'GEN INDEX - Age+Education+Housing+Displacement+Finance')

# %%
#Scaling genINDEX - 0-100
gdf_2010['gen_INDEX'] = scaler.fit_transform(gdf_2010[['gen_INDEX']])

# %%
fig,ax = plt.subplots(figsize=(15,15))
gdf_2010.plot(column='gen_INDEX',ax=ax,legend=True,cmap='OrRd')
plt.title('GEN INDEX Scaled 0-100- Age+Education+Housing+Displacement+Finance')
# Out:
# Text(0.5, 1.0, 'GEN INDEX Scaled 0-100- Age+Education+Housing+Displacement+Finance')

# %%
#Scaling genINDEX - 0-10
gdf_2010['gen_INDEX'] = scaler10.fit_transform(gdf_2010[['gen_INDEX']])

# %%
fig,ax = plt.subplots(figsize=(15,15))
gdf_2010.plot(column='gen_INDEX',ax=ax,legend=True,cmap='OrRd')
plt.title('GEN INDEX Scaled 0-10- Age+Education+Housing+Displacement+Finance')
# Out:
# Text(0.5, 1.0, 'GEN INDEX Scaled 0-10- Age+Education+Housing+Displacement+Finance')

# %%
#cmap with good info - tab10,Spectral

fig,ax = plt.subplots(figsize=(12,12))
gdf_2010.plot(column='gen_INDEX',ax=ax,legend=True,cmap='tab10')
plt.title('GEN INDEX Scaled 0-10- Age+Education+Housing+Displacement+Finance')
# Out:
# Text(0.5, 1.0, 'GEN INDEX Scaled 0-10- Age+Education+Housing+Displacement+Finance')

# %%
scaler5 = MinMaxScaler(feature_range=(1,5))
#Scaling genINDEX - 0-10
gdf_2010['gen_INDEX'] = scaler5.fit_transform(gdf_2010[['gen_INDEX']])

# %%
fig,ax = plt.subplots(figsize=(12,12))
gdf_2010.plot(column='gen_INDEX',ax=ax,legend=True,cmap='tab20')
plt.title('GEN INDEX - 2010')
# Out:
# Text(0.5, 1.0, 'GEN INDEX - 2010')

# %% [markdown]
# # Interactive Map

# %%
#gdf_2010.explore()

# %%
gdf_2010.explore(
     column="gen_INDEX", # make choropleth based on "BoroName" column
     tooltip="gen_INDEX", # show "BoroName" value in tooltip (on hover)
     popup=True, # show all values in popup (on click)
     tiles="CartoDB positron", # use "CartoDB positron" tiles
     cmap="tab20", # use "Set1" matplotlib colormap
     #style_kwds=dict(color="black") # use black outline
    )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-80744f361c52> in <module>
# ----> 1 gdf_2010.explore(
#       2      column="gen_INDEX", # make choropleth based on "BoroName" column
#       3      tooltip="gen_INDEX", # show "BoroName" value in tooltip (on hover)
#       4      popup=True, # show all values in popup (on click)
#       5      tiles="CartoDB positron", # use "CartoDB positron" tiles
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'GeoDataFrame' object has no attribute 'explore'

# %%
gdf_2010.to_file("UD_2010_Final_map/gdf_2010_final.shp")

# %% [markdown]
# # GEn INDEX v2

# %%
#GEN INDEX v2
e = 0.000000000001
gdf_2010['gen_INDEX_v2'] = \
((gdf_2010['frac_pop_25_to_54']+e)*\
(gdf_2010['Total_Bachelors_or_higher'].astype(float)+e)*\
#(gdf_2010['frac_Total_Houses_Built_2010_to_2019']+e)*\
(gdf_2010['frac_med_monthly_hous_cost']+e)*\
    gdf_2010['frac_high_income']+e)

# %%
#Scaling genINDEX - 0-5
#gdf_2010['gen_INDEX_v2'] = scaler5.fit_transform(gdf_2010[['gen_INDEX_v2']])

# %%
gdf_2010['gen_INDEX_v2'].sort_values(ascending=False)
# Out:
# 1177    1.583525e+07
# 1882    1.578298e+07
# 1821    1.468296e+07
# 1505    1.282113e+07
# 739     1.112639e+07
#             ...
# 2149    1.000000e-12
# 2136    1.000000e-12
# 1978    1.000000e-12
# 2023    1.000000e-12
# 2021    1.000000e-12
# Name: gen_INDEX_v2, Length: 2164, dtype: float64

# %%
#Removing values above 12 million

#store index values
temp = [i for i,v in enumerate(gdf_2010['gen_INDEX_v2']) if v > 12000000]

# %%
len(temp)
# Out:
# 4

# %%
#[[i,v] for i,v in enumerate(gdf_2010['gen_INDEX_v2']) if v > 12000000]

# %%
for i in range(len(temp)):
    gdf_2010['gen_INDEX_v2'].loc[temp[i]] = 0
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
#scaling by 100 after removing errorneous values
gdf_2010['gen_INDEX_v2'] = scaler.fit_transform(gdf_2010[['gen_INDEX_v2']])

# %%
fig,ax = plt.subplots(figsize=(15,15))
gdf_2010.plot(column='gen_INDEX_v2',legend=True,ax=ax,cmap='Blues')
plt.title('GEN INDEX - 2010')
#ax.set_facecolor('#22262d')
plt.show()

# %%
county_pop_avg_list_2010 = []
for i in range(1,6):
    county_pop_avg_list_2010.append(gdf_2010[gdf_2010['boro_code'] == i]['Total_Population'].mean())

# %%
county_pop_thresh = []
for i in range(5):
    county_pop_thresh.append(math.ceil(county_pop_avg_list_2010[i])*0.05) #take 5% as threshold for each county

# %%
county_pop_thresh
# Out:
# [274.90000000000003, 200.35000000000002, 162.3, 164.65, 210.70000000000002]

# %%
M_tract = gdf_2010[gdf_2010['boro_code'].astype(int) == 1]
Bx_tract = gdf_2010[gdf_2010['boro_code'].astype(int) == 2]
B_tract = gdf_2010[gdf_2010['boro_code'].astype(int) == 3]
Q_tract = gdf_2010[gdf_2010['boro_code'].astype(int) == 4]
S_tract = gdf_2010[gdf_2010['boro_code'].astype(int) == 5]

# %%
ingore_tracts_M = (M_tract[M_tract['Total_Population'].astype(int) < county_pop_thresh[0]]['Census_Tract']).index
ingore_tracts_Bx = (Bx_tract[Bx_tract['Total_Population'].astype(int) < county_pop_thresh[1]]['Census_Tract']).index
ingore_tracts_B = (B_tract[B_tract['Total_Population'].astype(int) < county_pop_thresh[2]]['Census_Tract']).index
ingore_tracts_Q = (Q_tract[Q_tract['Total_Population'].astype(int) < county_pop_thresh[3]]['Census_Tract']).index
ingore_tracts_S = (S_tract[S_tract['Total_Population'].astype(int) < county_pop_thresh[4]]['Census_Tract']).index

ingore_tracts_M = np.asarray(ingore_tracts_M)
ingore_tracts_Bx = np.asarray(ingore_tracts_Bx)
ingore_tracts_B = np.asarray(ingore_tracts_B)
ingore_tracts_Q = np.asarray(ingore_tracts_Q)
ingore_tracts_S = np.asarray(ingore_tracts_S)

# %%
Ignore_tracts_index = np.concatenate((ingore_tracts_M,ingore_tracts_Bx,ingore_tracts_B,ingore_tracts_Q,ingore_tracts_S))

# %%
Ignore_tracts_index
# Out:
# array([   2,    4,  596, 1018, 1019, 1021, 1022, 1178, 1485, 1515, 1649,
#        1824, 2093, 2149, 1173, 1211, 1372, 1406, 2051, 2052, 2117,  475,
#         674,  986,  993, 1459, 1654, 1658, 1840, 1968, 2015, 2021, 2054,
#        2157,  501,  678,  752,  792,  853,  981, 1036, 1063, 1071, 1134,
#        1414, 1562, 1604, 1650, 1808, 1875, 1891, 1903, 1946, 1984, 2005,
#        2018, 2023, 2029, 2049, 2155, 1999, 2038])

# %%
#setting gen score = 0 for above tracts
for i in range(len(Ignore_tracts_index)):
    gdf_2010['gen_INDEX_v2'].loc[Ignore_tracts_index[i]] = 0
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
fig,ax = plt.subplots(figsize=(15,15))
gdf_2010.plot(column='gen_INDEX_v2',legend=True,ax=ax,cmap='Blues')
plt.title('GEN INDEX - 2010')
#ax.set_facecolor('#22262d')
plt.show()

# %%
temp = pd.DataFrame(gdf_2010)
temp.to_csv('FINAL_GEN_2010.csv')

# %%
gdf_2010.to_file("UD_2010_Final_map/gdf_2010_final.shp")

# %% [markdown]
# ## cross-correlation of index features

# %%
gdf_2010.columns
# Out:
# Index(['ct2010', 'Census_Tract', 'boro_code', 'shape_area', 'shape_leng',
#        'geometry', 'Total_Population', 'Total_Male_Population',
#        'Total_Female_Population', 'Per_Population_25_to_34_yrs',
#        'Per_Population_35_to_44_yrs', 'Per_Population_45_to_54_yrs',
#        'Median_Age', 'Total_Population_18_to_24_yrs',
#        'Total_High_School_Graduates', 'Total_College_or_Associate_Degree',
#        'Total_Bachelors_or_higher', 'Total_Population_25_yrs_or_over',
#        'Total_Population_25_to_34_yrs', 'Total_House_Count',
#        'Total_Houses_Built_2005_to_2010', 'Total_Houses_Built_2000_to_2004',
#        'GEO_ID_x', 'tot_occ_hous_units', 'med_hh_income',
#        'med_monthly_hous_cost', 'GEO_ID_y', 'tot_fams', 'tot_fams_1-10k',
#        'tot_fams_10-15k', 'tot_fams_15-25k', 'frac_pop_25_to_54', 'gen_INDEX',
#        'frac_Total_Houses_Built_2000_to_2010', 'tot_fams_1-25k',
#        'frac_tot_fams_1-25k', 'frac_low_income', 'frac_high_income',
#        'frac_med_monthly_hous_cost', 'gen_INDEX_v2'],
#       dtype='object')

# %%
gdf_2010.Total_Bachelors_or_higher = gdf_2010.Total_Bachelors_or_higher.astype('float')

# %%
gdf_2010[['Total_Bachelors_or_higher', 'frac_high_income', 'frac_pop_25_to_54', 'frac_med_monthly_hous_cost', 'gen_INDEX_v2']].corr()
# Out:
#                             Total_Bachelors_or_higher  frac_high_income  \
# Total_Bachelors_or_higher                    1.000000          0.477422
# frac_high_income                             0.477422          1.000000
# frac_pop_25_to_54                            0.399642          0.353701
# frac_med_monthly_hous_cost                  -0.333373         -0.511941
# gen_INDEX_v2                                 0.840790          0.415096
#
#                             frac_pop_25_to_54  frac_med_monthly_hous_cost  \
# Total_Bachelors_or_higher            0.399642                   -0.333373
# frac_high_income                     0.353701                   -0.511941
# frac_pop_25_to_54                    1.000000                   -0.177164
# frac_med_monthly_hous_cost          -0.177164                    1.000000
# gen_INDEX_v2                         0.513831                   -0.108465
#
#                             gen_INDEX_v2
# Total_Bachelors_or_higher       0.840790
# frac_high_income                0.415096
# frac_pop_25_to_54               0.513831
# frac_med_monthly_hous_cost     -0.108465
# gen_INDEX_v2                    1.000000
